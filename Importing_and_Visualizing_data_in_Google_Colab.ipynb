# %%
from google.colab import drive
drive.mount('/content/DATA_SCI')
# Out:
# Mounted at /content/DATA_SCI

# %%
import pandas as pd
import matplotlib.pyplot as plt
mydata=pd.read_csv('/content/DATA_SCI/MyDrive/Share slim.csv')
print(mydata)
# Out:
#        name  gold
# 0       USA    46
# 1   Britain    27
# 2     China    26
# 3   Russian    19
# 4  Germany     27

# %%
#if you want the data to be in table form or charts
import pandas as pd
import matplotlib.pyplot as plt
mydata=pd.read_csv('/content/DATA_SCI/MyDrive/Share slim.csv')
(mydata)
# Out:
#        name  gold
# 0       USA    46
# 1   Britain    27
# 2     China    26
# 3   Russian    19
# 4  Germany     27

# %%
#importing files from drive mounted on Google colab (for the 1st 5 entities by use of .head(5))
import pandas as pd
mydata=pd.read_csv('/content/DATA_SCI/MyDrive/Share Elimu Schools.csv')
mydata.head(5)
# Out:
#    No                Secondary School Name  Gender  Elimu Scholars
# 0   1  A.I.C Secondary School - Loitokitok  Female              14
# 1   2                 Aga Khan High School    Male               1
# 2   3         Dr. Ribeiro Parklands School    Male              19
# 3   4                Eastleigh High School    Male               1
# 4   5    Elerai Mck Girls Secondary School  Female               1

# %%
#printing the entire document in the file
import pandas as pd
mydata=pd.read_csv('/content/DATA_SCI/MyDrive/Share Elimu Schools.csv')
(mydata)
# Out:
#     No                            Secondary School Name  \
# 0    1              A.I.C Secondary School - Loitokitok
# 1    2                             Aga Khan High School
# 2    3                     Dr. Ribeiro Parklands School
# 3    4                            Eastleigh High School
# 4    5                Elerai Mck Girls Secondary School
# 5    6               Embakasi Garrison Secondary School
# 6    7                     Enkii Boys' Secondary School
# 7    8                        Enkorika Secondary School
# 8    9                    Ewuaso Girls Secondary School
# 9   10             General Joseph Nkaissery High School
# 10  11        Highridge Girls Boarding Secondary School
# 11  12                  Ilbissil Girls Secondary School
# 12  13                       Ilkisonko Secondary School
# 13  14                     Isinya Boys Secondary School
# 14  15                 Kahawa Garrison Secondary School
# 15  16                          Kamiti Secondary School
# ...

# %%
#Visualization Code:
import matplotlib.pyplot as plt
import pandas as pd
mydata = pd.read_csv('/content/DATA_SCI/MyDrive/Share slim.csv')
country_data = mydata["name"]
medal_data = mydata["gold"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b"]
explode = (0.1, 0, 0, 0, 0)
plt.pie(medal_data, labels=country_data, explode=explode, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Gold medal achievements of five most successful\n"+"countries in 2023 Summer Olympics")
plt.show()

# %%
#BAR CHARTS:
#Visualization Code:
import matplotlib.pyplot as plt
import pandas as pd
mydata = pd.read_csv('/content/DATA_SCI/MyDrive/Share slim.csv')
country_data = mydata["name"]
medal_data = mydata["gold"]
plt.bar(country_data, medal_data, label="AWARD", color='#131720')
plt.plot()
plt.xlabel("country_data")
plt.ylabel("medal_data")
plt.title("Gold medal achievements of five most successful\n"+"countries in 2023 Summer Olympics")
plt.legend()
plt.show()

# %%
#LINE GRAPHS:
#Visualization Code:
import matplotlib.pyplot as plt
import pandas as pd
mydata = pd.read_csv('/content/DATA_SCI/MyDrive/Share slim.csv')
country_data = mydata["name"]
medal_data = mydata["gold"]
plt.plot(country_data, medal_data, label="Distribution",color='b')
plt.plot()
plt.xlabel("country_data")
plt.ylabel("medal_data")
plt.title("Gold medal achievements of five most successful\n"+"countries in 2023 Summer Olympics")
# Out:
# Text(0.5, 1.0, 'Gold medal achievements of five most successful\ncountries in 2023 Summer Olympics')

# %% [markdown]
# EXERCISE:
# Load the data below and generate a line graph for all the data sets given:
#
# PERSONNEL CONFIDENTIAL DETAILS
# Name    Age City    Salary
# John    30  New york    75000
# Alice   25  Las Angela's    68000
# Bob 35  Chikago 8000
# Sarah   28  San Francisco   9000
# Niko    32  Boston  82000

# %%
import matplotlib.pyplot as plt
import pandas as pd
mydata=pd.read_csv('/content/DATA_SCI/MyDrive/personal details new.csv')
(mydata)
Name_data=mydata["name"]
Age_data=mydata["age"]
City_data=mydata["city"]
Salary_data=mydata["salary"]
plt.plot(Name_data,Age_data, color='g',label='age')
plt.plot()
plt.xlabel('Names')
plt.ylabel('Age')
plt.title(' PERSONNEL CONFIDENTIAL DETAILS ')
plt.legend()
plt.show()

# %%
plt.plot(Name_data,City_data, color='r',label='city')
plt.plot()
plt.xlabel('Names')
plt.ylabel('city')
plt.title(' PERSONNEL CONFIDENTIAL DETAILS ')
plt.legend()
plt.show()

# %%
plt.plot(Name_data,Salary_data,color='b', label='salary')
plt.plot()
plt.xlabel('Names')
plt.ylabel('Salary')
plt.title(' PERSONNEL CONFIDENTIAL DETAILS ')
plt.legend()
plt.show()
